# %%
import os
import glob
import pandas as pd
import xml.etree.ElementTree as ET

# %%
def xml_to_csv(path):
    xml_list = []
    for xml_file in glob.glob(path + '/*.xml'):
        tree = ET.parse(xml_file)
        root = tree.getroot()
        for member in root.findall('object'):
            value = (root.find('filename').text,
                     int(root.find('size')[0].text),
                     int(root.find('size')[1].text),
                     member[0].text,
                     int(member[4][0].text),
                     int(member[4][1].text),
                     int(member[4][2].text),
                     int(member[4][3].text)
                     )
            xml_list.append(value)
    column_name = ['filename', 'width', 'height', 'class', 'xmin', 'ymin', 'xmax', 'ymax']
    xml_df = pd.DataFrame(xml_list, columns=column_name)
    return xml_df

# %%
def main():
    for i in range(1,401):
        image_path = os.path.join(os.getcwd(), "trening/P"+str(i))
        xml_df = xml_to_csv(image_path)
        xml_df.to_csv('trening/P'+str(i)+".csv", index=None)
        print('Successfully converted',i,' xml to csv.')

# %%
main()
# Out:
# ('Successfully converted', 1, ' xml to csv.')
# ('Successfully converted', 2, ' xml to csv.')
# ('Successfully converted', 3, ' xml to csv.')
# ('Successfully converted', 4, ' xml to csv.')
# ('Successfully converted', 5, ' xml to csv.')
# ('Successfully converted', 6, ' xml to csv.')
# ('Successfully converted', 7, ' xml to csv.')
# ('Successfully converted', 8, ' xml to csv.')
# ('Successfully converted', 9, ' xml to csv.')
# ('Successfully converted', 10, ' xml to csv.')
# ('Successfully converted', 11, ' xml to csv.')
# ('Successfully converted', 12, ' xml to csv.')
# ('Successfully converted', 13, ' xml to csv.')
# ('Successfully converted', 14, ' xml to csv.')
# ('Successfully converted', 15, ' xml to csv.')
# ('Successfully converted', 16, ' xml to csv.')
# ('Successfully converted', 17, ' xml to csv.')
# ('Successfully converted', 18, ' xml to csv.')
# ('Successfully converted', 19, ' xml to csv.')
# ('Successfully converted', 20, ' xml to csv.')
# ('Successfully converted', 21, ' xml to csv.')
# ('Successfully converted', 22, ' xml to csv.')
# ('Successfully converted', 23, ' xml to csv.')
# ('Successfully converted', 24, ' xml to csv.')
# ('Successfully converted', 25, ' xml to csv.')
# ('Successfully converted', 26, ' xml to csv.')
# ('Successfully converted', 27, ' xml to csv.')
# ('Successfully converted', 28, ' xml to csv.')
# ('Successfully converted', 29, ' xml to csv.')
# ('Successfully converted', 30, ' xml to csv.')
# ('Successfully converted', 31, ' xml to csv.')
# ('Successfully converted', 32, ' xml to csv.')
# ('Successfully converted', 33, ' xml to csv.')
# ('Successfully converted', 34, ' xml to csv.')
# ('Successfully converted', 35, ' xml to csv.')
# ('Successfully converted', 36, ' xml to csv.')
# ('Successfully converted', 37, ' xml to csv.')
# ('Successfully converted', 38, ' xml to csv.')
# ('Successfully converted', 39, ' xml to csv.')
# ('Successfully converted', 40, ' xml to csv.')
# ('Successfully converted', 41, ' xml to csv.')
# ('Successfully converted', 42, ' xml to csv.')
# ('Successfully converted', 43, ' xml to csv.')
# ('Successfully converted', 44, ' xml to csv.')
# ('Successfully converted', 45, ' xml to csv.')
# ('Successfully converted', 46, ' xml to csv.')
# ('Successfully converted', 47, ' xml to csv.')
# ('Successfully converted', 48, ' xml to csv.')
# ('Successfully converted', 49, ' xml to csv.')
# ('Successfully converted', 50, ' xml to csv.')
# ('Successfully converted', 51, ' xml to csv.')
# ('Successfully converted', 52, ' xml to csv.')
# ('Successfully converted', 53, ' xml to csv.')
# ('Successfully converted', 54, ' xml to csv.')
# ('Successfully converted', 55, ' xml to csv.')
# ('Successfully converted', 56, ' xml to csv.')
# ('Successfully converted', 57, ' xml to csv.')
# ('Successfully converted', 58, ' xml to csv.')
# ('Successfully converted', 59, ' xml to csv.')
# ('Successfully converted', 60, ' xml to csv.')
# ('Successfully converted', 61, ' xml to csv.')
# ('Successfully converted', 62, ' xml to csv.')
# ('Successfully converted', 63, ' xml to csv.')
# ('Successfully converted', 64, ' xml to csv.')
# ('Successfully converted', 65, ' xml to csv.')
# ('Successfully converted', 66, ' xml to csv.')
# ('Successfully converted', 67, ' xml to csv.')
# ('Successfully converted', 68, ' xml to csv.')
# ('Successfully converted', 69, ' xml to csv.')
# ('Successfully converted', 70, ' xml to csv.')
# ('Successfully converted', 71, ' xml to csv.')
# ('Successfully converted', 72, ' xml to csv.')
# ('Successfully converted', 73, ' xml to csv.')
# ('Successfully converted', 74, ' xml to csv.')
# ('Successfully converted', 75, ' xml to csv.')
# ('Successfully converted', 76, ' xml to csv.')
# ('Successfully converted', 77, ' xml to csv.')
# ('Successfully converted', 78, ' xml to csv.')
# ('Successfully converted', 79, ' xml to csv.')
# ('Successfully converted', 80, ' xml to csv.')
# ('Successfully converted', 81, ' xml to csv.')
# ('Successfully converted', 82, ' xml to csv.')
# ('Successfully converted', 83, ' xml to csv.')
# ('Successfully converted', 84, ' xml to csv.')
# ('Successfully converted', 85, ' xml to csv.')
# ('Successfully converted', 86, ' xml to csv.')
# ('Successfully converted', 87, ' xml to csv.')
# ('Successfully converted', 88, ' xml to csv.')
# ('Successfully converted', 89, ' xml to csv.')
# ('Successfully converted', 90, ' xml to csv.')
# ('Successfully converted', 91, ' xml to csv.')
# ('Successfully converted', 92, ' xml to csv.')
# ('Successfully converted', 93, ' xml to csv.')
# ('Successfully converted', 94, ' xml to csv.')
# ('Successfully converted', 95, ' xml to csv.')
# ('Successfully converted', 96, ' xml to csv.')
# ('Successfully converted', 97, ' xml to csv.')
# ('Successfully converted', 98, ' xml to csv.')
# ('Successfully converted', 99, ' xml to csv.')
# ('Successfully converted', 100, ' xml to csv.')
# ('Successfully converted', 101, ' xml to csv.')
# ('Successfully converted', 102, ' xml to csv.')
# ('Successfully converted', 103, ' xml to csv.')
# ('Successfully converted', 104, ' xml to csv.')
# ('Successfully converted', 105, ' xml to csv.')
# ('Successfully converted', 106, ' xml to csv.')
# ('Successfully converted', 107, ' xml to csv.')
# ('Successfully converted', 108, ' xml to csv.')
# ('Successfully converted', 109, ' xml to csv.')
# ('Successfully converted', 110, ' xml to csv.')
# ('Successfully converted', 111, ' xml to csv.')
# ('Successfully converted', 112, ' xml to csv.')
# ('Successfully converted', 113, ' xml to csv.')
# ('Successfully converted', 114, ' xml to csv.')
# ('Successfully converted', 115, ' xml to csv.')
# ('Successfully converted', 116, ' xml to csv.')
# ('Successfully converted', 117, ' xml to csv.')
# ('Successfully converted', 118, ' xml to csv.')
# ('Successfully converted', 119, ' xml to csv.')
# ('Successfully converted', 120, ' xml to csv.')
# ('Successfully converted', 121, ' xml to csv.')
# ('Successfully converted', 122, ' xml to csv.')
# ('Successfully converted', 123, ' xml to csv.')
# ('Successfully converted', 124, ' xml to csv.')
# ('Successfully converted', 125, ' xml to csv.')
# ('Successfully converted', 126, ' xml to csv.')
# ('Successfully converted', 127, ' xml to csv.')
# ('Successfully converted', 128, ' xml to csv.')
# ('Successfully converted', 129, ' xml to csv.')
# ('Successfully converted', 130, ' xml to csv.')
# ('Successfully converted', 131, ' xml to csv.')
# ('Successfully converted', 132, ' xml to csv.')
# ('Successfully converted', 133, ' xml to csv.')
# ('Successfully converted', 134, ' xml to csv.')
# ('Successfully converted', 135, ' xml to csv.')
# ('Successfully converted', 136, ' xml to csv.')
# ('Successfully converted', 137, ' xml to csv.')
# ('Successfully converted', 138, ' xml to csv.')
# ('Successfully converted', 139, ' xml to csv.')
# ('Successfully converted', 140, ' xml to csv.')
# ('Successfully converted', 141, ' xml to csv.')
# ('Successfully converted', 142, ' xml to csv.')
# ('Successfully converted', 143, ' xml to csv.')
# ('Successfully converted', 144, ' xml to csv.')
# ('Successfully converted', 145, ' xml to csv.')
# ('Successfully converted', 146, ' xml to csv.')
# ('Successfully converted', 147, ' xml to csv.')
# ('Successfully converted', 148, ' xml to csv.')
# ('Successfully converted', 149, ' xml to csv.')
# ('Successfully converted', 150, ' xml to csv.')
# ('Successfully converted', 151, ' xml to csv.')
# ('Successfully converted', 152, ' xml to csv.')
# ('Successfully converted', 153, ' xml to csv.')
# ('Successfully converted', 154, ' xml to csv.')
# ('Successfully converted', 155, ' xml to csv.')
# ('Successfully converted', 156, ' xml to csv.')
# ('Successfully converted', 157, ' xml to csv.')
# ('Successfully converted', 158, ' xml to csv.')
# ('Successfully converted', 159, ' xml to csv.')
# ('Successfully converted', 160, ' xml to csv.')
# ('Successfully converted', 161, ' xml to csv.')
# ('Successfully converted', 162, ' xml to csv.')
# ('Successfully converted', 163, ' xml to csv.')
# ('Successfully converted', 164, ' xml to csv.')
# ('Successfully converted', 165, ' xml to csv.')
# ('Successfully converted', 166, ' xml to csv.')
# ('Successfully converted', 167, ' xml to csv.')
# ('Successfully converted', 168, ' xml to csv.')
# ('Successfully converted', 169, ' xml to csv.')
# ('Successfully converted', 170, ' xml to csv.')
# ('Successfully converted', 171, ' xml to csv.')
# ('Successfully converted', 172, ' xml to csv.')
# ('Successfully converted', 173, ' xml to csv.')
# ('Successfully converted', 174, ' xml to csv.')
# ('Successfully converted', 175, ' xml to csv.')
# ('Successfully converted', 176, ' xml to csv.')
# ('Successfully converted', 177, ' xml to csv.')
# ('Successfully converted', 178, ' xml to csv.')
# ('Successfully converted', 179, ' xml to csv.')
# ('Successfully converted', 180, ' xml to csv.')
# ('Successfully converted', 181, ' xml to csv.')
# ('Successfully converted', 182, ' xml to csv.')
# ('Successfully converted', 183, ' xml to csv.')
# ('Successfully converted', 184, ' xml to csv.')
# ('Successfully converted', 185, ' xml to csv.')
# ('Successfully converted', 186, ' xml to csv.')
# ('Successfully converted', 187, ' xml to csv.')
# ('Successfully converted', 188, ' xml to csv.')
# ('Successfully converted', 189, ' xml to csv.')
# ('Successfully converted', 190, ' xml to csv.')
# ('Successfully converted', 191, ' xml to csv.')
# ('Successfully converted', 192, ' xml to csv.')
# ('Successfully converted', 193, ' xml to csv.')
# ('Successfully converted', 194, ' xml to csv.')
# ('Successfully converted', 195, ' xml to csv.')
# ('Successfully converted', 196, ' xml to csv.')
# ('Successfully converted', 197, ' xml to csv.')
# ('Successfully converted', 198, ' xml to csv.')
# ('Successfully converted', 199, ' xml to csv.')
# ('Successfully converted', 200, ' xml to csv.')
# ('Successfully converted', 201, ' xml to csv.')
# ('Successfully converted', 202, ' xml to csv.')
# ('Successfully converted', 203, ' xml to csv.')
# ('Successfully converted', 204, ' xml to csv.')
# ('Successfully converted', 205, ' xml to csv.')
# ('Successfully converted', 206, ' xml to csv.')
# ('Successfully converted', 207, ' xml to csv.')
# ('Successfully converted', 208, ' xml to csv.')
# ('Successfully converted', 209, ' xml to csv.')
# ('Successfully converted', 210, ' xml to csv.')
# ('Successfully converted', 211, ' xml to csv.')
# ('Successfully converted', 212, ' xml to csv.')
# ('Successfully converted', 213, ' xml to csv.')
# ('Successfully converted', 214, ' xml to csv.')
# ('Successfully converted', 215, ' xml to csv.')
# ('Successfully converted', 216, ' xml to csv.')
# ('Successfully converted', 217, ' xml to csv.')
# ('Successfully converted', 218, ' xml to csv.')
# ('Successfully converted', 219, ' xml to csv.')
# ('Successfully converted', 220, ' xml to csv.')
# ('Successfully converted', 221, ' xml to csv.')
# ('Successfully converted', 222, ' xml to csv.')
# ('Successfully converted', 223, ' xml to csv.')
# ('Successfully converted', 224, ' xml to csv.')
# ('Successfully converted', 225, ' xml to csv.')
# ('Successfully converted', 226, ' xml to csv.')
# ('Successfully converted', 227, ' xml to csv.')
# ('Successfully converted', 228, ' xml to csv.')
# ('Successfully converted', 229, ' xml to csv.')
# ('Successfully converted', 230, ' xml to csv.')
# ('Successfully converted', 231, ' xml to csv.')
# ('Successfully converted', 232, ' xml to csv.')
# ('Successfully converted', 233, ' xml to csv.')
# ('Successfully converted', 234, ' xml to csv.')
# ('Successfully converted', 235, ' xml to csv.')
# ('Successfully converted', 236, ' xml to csv.')
# ('Successfully converted', 237, ' xml to csv.')
# ('Successfully converted', 238, ' xml to csv.')
# ('Successfully converted', 239, ' xml to csv.')
# ('Successfully converted', 240, ' xml to csv.')
# ('Successfully converted', 241, ' xml to csv.')
# ('Successfully converted', 242, ' xml to csv.')
# ('Successfully converted', 243, ' xml to csv.')
# ('Successfully converted', 244, ' xml to csv.')
# ('Successfully converted', 245, ' xml to csv.')
# ('Successfully converted', 246, ' xml to csv.')
# ('Successfully converted', 247, ' xml to csv.')
# ('Successfully converted', 248, ' xml to csv.')
# ('Successfully converted', 249, ' xml to csv.')
# ('Successfully converted', 250, ' xml to csv.')
# ('Successfully converted', 251, ' xml to csv.')
# ('Successfully converted', 252, ' xml to csv.')
# ('Successfully converted', 253, ' xml to csv.')
# ('Successfully converted', 254, ' xml to csv.')
# ('Successfully converted', 255, ' xml to csv.')
# ('Successfully converted', 256, ' xml to csv.')
# ('Successfully converted', 257, ' xml to csv.')
# ('Successfully converted', 258, ' xml to csv.')
# ('Successfully converted', 259, ' xml to csv.')
# ('Successfully converted', 260, ' xml to csv.')
# ('Successfully converted', 261, ' xml to csv.')
# ('Successfully converted', 262, ' xml to csv.')
# ('Successfully converted', 263, ' xml to csv.')
# ('Successfully converted', 264, ' xml to csv.')
# ('Successfully converted', 265, ' xml to csv.')
# ('Successfully converted', 266, ' xml to csv.')
# ('Successfully converted', 267, ' xml to csv.')
# ('Successfully converted', 268, ' xml to csv.')
# ('Successfully converted', 269, ' xml to csv.')
# ('Successfully converted', 270, ' xml to csv.')
# ('Successfully converted', 271, ' xml to csv.')
# ('Successfully converted', 272, ' xml to csv.')
# ('Successfully converted', 273, ' xml to csv.')
# ('Successfully converted', 274, ' xml to csv.')
# ('Successfully converted', 275, ' xml to csv.')
# ('Successfully converted', 276, ' xml to csv.')
# ('Successfully converted', 277, ' xml to csv.')
# ('Successfully converted', 278, ' xml to csv.')
# ('Successfully converted', 279, ' xml to csv.')
# ('Successfully converted', 280, ' xml to csv.')
# ('Successfully converted', 281, ' xml to csv.')
# ('Successfully converted', 282, ' xml to csv.')
# ('Successfully converted', 283, ' xml to csv.')
# ('Successfully converted', 284, ' xml to csv.')
# ('Successfully converted', 285, ' xml to csv.')
# ('Successfully converted', 286, ' xml to csv.')
# ('Successfully converted', 287, ' xml to csv.')
# ('Successfully converted', 288, ' xml to csv.')
# ('Successfully converted', 289, ' xml to csv.')
# ('Successfully converted', 290, ' xml to csv.')
# ('Successfully converted', 291, ' xml to csv.')
# ('Successfully converted', 292, ' xml to csv.')
# ('Successfully converted', 293, ' xml to csv.')
# ('Successfully converted', 294, ' xml to csv.')
# ('Successfully converted', 295, ' xml to csv.')
# ('Successfully converted', 296, ' xml to csv.')
# ('Successfully converted', 297, ' xml to csv.')
# ('Successfully converted', 298, ' xml to csv.')
# ('Successfully converted', 299, ' xml to csv.')
# ('Successfully converted', 300, ' xml to csv.')
# ('Successfully converted', 301, ' xml to csv.')
# ('Successfully converted', 302, ' xml to csv.')
# ('Successfully converted', 303, ' xml to csv.')
# ('Successfully converted', 304, ' xml to csv.')
# ('Successfully converted', 305, ' xml to csv.')
# ('Successfully converted', 306, ' xml to csv.')
# ('Successfully converted', 307, ' xml to csv.')
# ('Successfully converted', 308, ' xml to csv.')
# ('Successfully converted', 309, ' xml to csv.')
# ('Successfully converted', 310, ' xml to csv.')
# ('Successfully converted', 311, ' xml to csv.')
# ('Successfully converted', 312, ' xml to csv.')
# ('Successfully converted', 313, ' xml to csv.')
# ('Successfully converted', 314, ' xml to csv.')
# ('Successfully converted', 315, ' xml to csv.')
# ('Successfully converted', 316, ' xml to csv.')
# ('Successfully converted', 317, ' xml to csv.')
# ('Successfully converted', 318, ' xml to csv.')
# ('Successfully converted', 319, ' xml to csv.')
# ('Successfully converted', 320, ' xml to csv.')
# ('Successfully converted', 321, ' xml to csv.')
# ('Successfully converted', 322, ' xml to csv.')
# ('Successfully converted', 323, ' xml to csv.')
# ('Successfully converted', 324, ' xml to csv.')
# ('Successfully converted', 325, ' xml to csv.')
# ('Successfully converted', 326, ' xml to csv.')
# ('Successfully converted', 327, ' xml to csv.')
# ('Successfully converted', 328, ' xml to csv.')
# ('Successfully converted', 329, ' xml to csv.')
# ('Successfully converted', 330, ' xml to csv.')
# ('Successfully converted', 331, ' xml to csv.')
# ('Successfully converted', 332, ' xml to csv.')
# ('Successfully converted', 333, ' xml to csv.')
# ('Successfully converted', 334, ' xml to csv.')
# ('Successfully converted', 335, ' xml to csv.')
# ('Successfully converted', 336, ' xml to csv.')
# ('Successfully converted', 337, ' xml to csv.')
# ('Successfully converted', 338, ' xml to csv.')
# ('Successfully converted', 339, ' xml to csv.')
# ('Successfully converted', 340, ' xml to csv.')
# ('Successfully converted', 341, ' xml to csv.')
# ('Successfully converted', 342, ' xml to csv.')
# ('Successfully converted', 343, ' xml to csv.')
# ('Successfully converted', 344, ' xml to csv.')
# ('Successfully converted', 345, ' xml to csv.')
# ('Successfully converted', 346, ' xml to csv.')
# ('Successfully converted', 347, ' xml to csv.')
# ('Successfully converted', 348, ' xml to csv.')
# ('Successfully converted', 349, ' xml to csv.')
# ('Successfully converted', 350, ' xml to csv.')
# ('Successfully converted', 351, ' xml to csv.')
# ('Successfully converted', 352, ' xml to csv.')
# ('Successfully converted', 353, ' xml to csv.')
# ('Successfully converted', 354, ' xml to csv.')
# ('Successfully converted', 355, ' xml to csv.')
# ('Successfully converted', 356, ' xml to csv.')
# ('Successfully converted', 357, ' xml to csv.')
# ('Successfully converted', 358, ' xml to csv.')
# ('Successfully converted', 359, ' xml to csv.')
# ('Successfully converted', 360, ' xml to csv.')
# ('Successfully converted', 361, ' xml to csv.')
# ('Successfully converted', 362, ' xml to csv.')
# ('Successfully converted', 363, ' xml to csv.')
# ('Successfully converted', 364, ' xml to csv.')
# ('Successfully converted', 365, ' xml to csv.')
# ('Successfully converted', 366, ' xml to csv.')
# ('Successfully converted', 367, ' xml to csv.')
# ('Successfully converted', 368, ' xml to csv.')
# ('Successfully converted', 369, ' xml to csv.')
# ('Successfully converted', 370, ' xml to csv.')
# ('Successfully converted', 371, ' xml to csv.')
# ('Successfully converted', 372, ' xml to csv.')
# ('Successfully converted', 373, ' xml to csv.')
# ('Successfully converted', 374, ' xml to csv.')
# ('Successfully converted', 375, ' xml to csv.')
# ('Successfully converted', 376, ' xml to csv.')
# ('Successfully converted', 377, ' xml to csv.')
# ('Successfully converted', 378, ' xml to csv.')
# ('Successfully converted', 379, ' xml to csv.')
# ('Successfully converted', 380, ' xml to csv.')
# ('Successfully converted', 381, ' xml to csv.')
# ('Successfully converted', 382, ' xml to csv.')
# ('Successfully converted', 383, ' xml to csv.')
# ('Successfully converted', 384, ' xml to csv.')
# ('Successfully converted', 385, ' xml to csv.')
# ('Successfully converted', 386, ' xml to csv.')
# ('Successfully converted', 387, ' xml to csv.')
# ('Successfully converted', 388, ' xml to csv.')
# ('Successfully converted', 389, ' xml to csv.')
# ('Successfully converted', 390, ' xml to csv.')
# ('Successfully converted', 391, ' xml to csv.')
# ('Successfully converted', 392, ' xml to csv.')
# ('Successfully converted', 393, ' xml to csv.')
# ('Successfully converted', 394, ' xml to csv.')
# ('Successfully converted', 395, ' xml to csv.')
# ('Successfully converted', 396, ' xml to csv.')
# ('Successfully converted', 397, ' xml to csv.')
# ('Successfully converted', 398, ' xml to csv.')
# ('Successfully converted', 399, ' xml to csv.')
# ('Successfully converted', 400, ' xml to csv.')
